# %%
import pandas as pd

# %%
from fetch_gdelt_data import fetch_df
import datetime

# %%
fetch_df(datetime.date(2017, 11,30), translingual=True)[-10:]
# Out:
#                     Day  MonthYear  Year  FractionDate Actor1Code  Actor1Name  \
# GlobalEventID
# 711400776      20171130     201711  2017     2017.9041     VENJUD  VENEZUELAN
# 711400777      20171130     201711  2017     2017.9041        YEM       YEMEN
# 711400778      20171130     201711  2017     2017.9041        YEM       YEMEN
# 711400779      20171130     201711  2017     2017.9041        YEM       YEMEN
# 711400780      20171130     201711  2017     2017.9041        YEM       YEMEN
# 711400781      20171130     201711  2017     2017.9041        YEM       YEMEN
# 711400782      20171130     201711  2017     2017.9041        ZAF  NORTH WEST
# 711400783      20171130     201711  2017     2017.9041        bos    BOSNIAKS
# 711400784      20171130     201711  2017     2017.9041        glg    GALICIAN
# 711400785      20171130     201711  2017     2017.9041     menGOV       MENDE
#
#               Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# GlobalEventID
# ...

# %%
columns = ['EventCode', 'SOURCEURL', 'ActionGeo_CountryCode', 'ActionGeo_Lat', 'ActionGeo_Long',
                   'IsRootEvent', 'QuadClass', 'GoldsteinScale', 'AvgTone',
                   'NumMentions', 'NumSources', 'NumArticles', 'ActionGeo_Type', 'Day',
           'Country_Code', 'Country_Source', 'Country_Name']


df_all = pd.read_csv('all_cleaned_data_bis.csv', names=columns, encoding='latin-1')

# %%
df_all_reduced = df_all[['EventCode', 'ActionGeo_CountryCode', 'ActionGeo_Lat', 'ActionGeo_Long',
                   'IsRootEvent', 'QuadClass', 'GoldsteinScale', 'AvgTone',
                   'NumMentions', 'NumSources', 'NumArticles', 'ActionGeo_Type', 'Day',
           'Country_Code', 'Country_Source', 'Country_Name']]

# %%
with open('all_cleaned_data_no_url.csv', 'w') as f:
        df_all_reduced.to_csv(f, header=False, encoding='utf-8')
